# %%
import pandas as pd 
df = pd.read_parquet('/Users/ayushjain/Development/Research/NLA/nla-fraud/data/summaries.parquet')

# %%
df.head()
# Out:
#    row_idx                                  activation_vector  \
# 0   263584  [0.7573064565658569, 0.1356651335954666, -0.14...
# 1   290447  [0.5627380609512329, -0.1424444019794464, -0.0...
# 2   201710  [-0.169817715883255, -0.16187089681625366, -0....
# 3    39223  [0.070592500269413, -0.15105007588863373, -0.1...
# 4   222177  [0.28421464562416077, 0.46205833554267883, -0....
#
#                             activation_vector_normed  \
# 0  [0.2239867001771927, 0.040125347673892975, -0....
# 1  [0.1590173840522766, -0.04025164991617203, -0....
# 2  [-0.09648092836141586, -0.09196598827838898, -...
# 3  [0.03204130381345749, -0.06856027245521545, -0...
# 4  [0.10352408140897751, 0.16830295324325562, -0....
#
#                                              summary  \
# 0  - $30.00 → Low amount reduces fraud risk (comm...
# 1  - $26.95 → Low amount reduces fraud risk (typi...
# 2  - $18.42 → Low amount reduces fraud score (typ...
# ...
